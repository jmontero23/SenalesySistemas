# %% [markdown]
# <a href="https://colab.research.google.com/github/jmontero23/SenalesySistemas/blob/main/Proyecto/Proyecto_SyS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proyecto Final SyS 2025-1: Conceptos Clave**
#
# **Introducción**
# Este cuaderno presenta un resumen de los conceptos teóricos fundamentales para el desarrollo del proyecto **"De Fourier al WiFi/5G"**[^1]. Cada sección incluye el modelado matemático y sus aplicaciones, con referencias a la literatura académica estándar en procesamiento de señales y comunicaciones digitales.
#
# ---
#
# ### **1. Transformada de Fourier (FT, DFT, FFT)**
#
# - **Descripción:**
#   La Transformada de Fourier descompone una señal en el dominio del tiempo hacia el dominio de la frecuencia, revelando sus componentes senoidales[^2]. Su versión discreta, la DFT, es esencial en el procesamiento digital de señales[^3]. La FFT es un algoritmo eficiente para calcular la DFT[^2].
#
# - **Modelado Matemático (DFT):**
#   $$
#   X[k] = \sum_{n=0}^{N-1} x[n] \cdot e^{-j2\pi kn/N}
#   $$
#
# - **Usos Principales:**
#   Análisis espectral, filtrado en frecuencia y base de la multiplexación OFDM[^3][^4].
#
# ---
#
# ### **2. Filtrado Digital (FIR/IIR)**
#
# - **Descripción:**
#   El filtrado digital permite modificar el contenido espectral de una señal[^5][^6].
#   - **FIR:** Respuesta finita, estable, permite fase lineal.
#   - **IIR:** Respuesta infinita, más eficiente, pero requiere cuidado para mantener la estabilidad[^6].
#
# - **Modelado Matemático (Filtro FIR):**
#   $$
#   y[n] = \sum_{k=0}^{M} b_k \cdot x[n-k]
#   $$
#
# - **Usos Principales:**
#   Eliminación de ruido, selección de bandas, acondicionamiento de señales[^5].
#
# ---
#
# ### **3. Señales Analíticas y Transformada de Hilbert**
#
# - **Descripción:**
#   La Transformada de Hilbert aplica un desfase de \( -90° \) a todas las componentes de frecuencia[^7]. La señal analítica combina la señal original (parte real) con su Hilbert (parte imaginaria)[^8].
#
# - **Modelado Matemático:**
#   $$
#   x_a(t) = x(t) + j\hat{x}(t)
#   $$
#
# - **Usos Principales:**
#   Generación de señales I/Q para modulación compleja[^7][^9].
#
# ---
#
# ### **4. Señales I/Q y Modulación QAM**
#
# - **Descripción:**
#   QAM modula dos señales independientes:
#   - I (en fase) con coseno
#   - Q (cuadratura) con seno desfasado 90°[^10].
#   La combinación de amplitudes para I y Q codifica múltiples bits por símbolo, visualizado en un diagrama de constelación[^11].
#
# - **Modelado Matemático:**
#   $$
#   s(t) = I(t) \cos(2\pi f_c t) - Q(t) \sin(2\pi f_c t)
#   $$
#
# - **Usos Principales:**
#   Alta eficiencia espectral. Base en WiFi, 5G y otros sistemas digitales[^12].
#
# ---
#
# ### **5. OFDM y Comunicaciones WiFi/5G**
#
# - **Descripción:**
#   OFDM divide un canal rápido en muchas subportadoras ortogonales de baja velocidad[^4]. Esto lo hace resistente a interferencias y desvanecimientos en canales inalámbricos.
#
# - **Relación con Conceptos Anteriores:**
#   - Usa FFT/IFFT para modular y demodular.
#   - Cada subportadora se modula con QAM[^12].
#
# - **Uso en WiFi/5G:**
#   Esquema base de la capa física de estándares modernos como WiFi y 5G[^13].
#
# ---
#
# ### **Referencias Académicas 📚**
#
# [^1]: Marino Álvarez Meza, A. (2024). *De Fourier al WiFi/5G: Anatomía de una Señal Inalámbrica*.
# [^2]: Oppenheim, A. V., & Schafer, R. W. (2010). *Discrete-Time Signal Processing* (3rd ed.). Pearson.
# [^3]: Mitra, S. K. (2011). *Digital Signal Processing: A Computer-Based Approach* (4th ed.). McGraw-Hill.
# [^4]: Goldsmith, A. (2005). *Wireless Communications*. Cambridge University Press.
# [^5]: Sklar, B. (2001). *Digital Communications: Fundamentals and Applications* (2nd ed.). Pearson.
# [^6]: Lathi, B. P., & Ding, Z. (2009). *Modern Digital and Analog Communication Systems* (4th ed.). Oxford University Press.
# [^7]: Proakis, J. G., & Salehi, M. (2008). *Digital Communications* (5th ed.). McGraw-Hill.
# [^8]: Haykin, S. (2001). *Communication Systems* (4th ed.). Wiley.
# [^9]: Tse, D., & Viswanath, P. (2005). *Fundamentals of Wireless Communication*. Cambridge University Press.
# [^10]: Rappaport, T. S. (2014). *Wireless Communications: Principles and Practice* (2nd ed.). Pearson.
# [^11]: Proakis & Salehi, op. cit., capítulo de QAM.
# [^12]: Goldsmith, op. cit., sección OFDM.
# [^13]: Tse & Viswanath, op. cit., sección sobre 5G y OFDM.
